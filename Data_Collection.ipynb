# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

cities = [
    "pune", "mumbai", "bangalore", "hyderabad", "chennai", "delhi", "gurgaon",
    "noida", "kolkata", "ahmedabad", "jaipur", "surat", "indore", "nagpur", "coimbatore"
]

num_pages = 7  # number of pages per city
all_properties = []

headers = {"User-Agent": "Mozilla/5.0"}

for city in cities:
    for page in range(1, num_pages + 1):
        url = f"https://www.squareyards.com/sale/property-for-sale-in-{city}?page={page}"
        print(f"Fetching data from {url}")
        
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"❌ Failed for {city} - Page {page}")
            continue

        soup = BeautifulSoup(response.text, "html.parser")
        listings = soup.find_all("div", class_="lead-box")

        for listing in listings:
            button = listing.find("button")
            if not button:
                continue

            # Extract attributes safely using .get()
            property_data = {
                "City": button.get("cityname"),
                "Location": button.get("location"),
                "Project Name": button.get("projectname"),
                "Prjname":button.get("prjname"),
                
                "Property Title": button.get("propertytitle"),
                "Property Type": button.get("propertytype"),
                "Unit Type": button.get("unittype"),
                "Area": button.get("sublocalityname"),
                "Price (₹)": button.get("totalprice"),
                "Agent Name": button.get("username"),
                "Property Link": button.get("propertylink")
            }

            all_properties.append(property_data)
        
        # Sleep to avoid getting blocked
        time.sleep(2)

# Convert to DataFrame
df = pd.DataFrame(all_properties)
print(f"\n✅ Total Properties Extracted: {len(df)}")
print(df.head())

# Save to CSV
df.to_csv("real_estate_data.csv", index=False)
print("\n💾 Data saved to 'real_estate_data.csv'")
# Out:
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-pune?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-mumbai?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-bangalore?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-hyderabad?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-chennai?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-delhi?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-gurgaon?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-noida?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-kolkata?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-ahmedabad?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-jaipur?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-surat?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-indore?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-nagpur?page=7
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=1
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=2
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=3
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=4
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=5
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=6
# Fetching data from https://www.squareyards.com/sale/property-for-sale-in-coimbatore?page=7
#
# ✅ Total Properties Extracted: 3072
#    City            Location                        Project Name  \
# 0  Pune     Hinjewadi, Pune              Vinode Vantage Capital
# 1  None  Keshav Nagar, Pune                                None
# 2  Pune        Nanded, Pune  Dharmavat Sunder Sanskruti Phase 3
# 3  Pune        Nanded, Pune                 Nanded City Asawari
# 4  Pune       Dhanori, Pune                    Magnum lifestyle
#
#                                       Property Title Property Type Unit Type  \
# 0  1050 Sq.Ft. Retail Shop in Vinode Vantage Capital          Shop      Shop
# 1                                               None          None      None
# 2  2 BHK 1300 Sq.Ft. Apartment in Dharmavat Sunde...     Apartment     2 BHK
# 3  2 BHK + Extra Room 872 Sq.Ft. Apartment in Nan...     Apartment     2 BHK
# 4     1 BHK 390 Sq.Ft. Apartment in Magnum lifestyle     Apartment     1 BHK
#
#         Area Price (₹)               Agent Name  \
# 0  Hinjewadi  38000000               Vinit Mali
# 1       None      None                     None
# 2     Nanded  11000000         GHODKE PROPERTY
# 3     Nanded   8400000        Preet Properties
# 4    Dhanori   3500000  MUSHTAK IBRAHIM SHAIKH
#
#                                        Property Link
# 0  https://www.squareyards.com/resale-1050-sq-ft-...
# 1                                               None
# 2  https://www.squareyards.com/resale-2-bhk-1300-...
# 3  https://www.squareyards.com/resale-2-bhk-extra...
# 4  https://www.squareyards.com/resale-1-bhk-390-s...
#
# 💾 Data saved to 'real_estate_data.csv'
